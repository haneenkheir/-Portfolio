# %% [markdown]
# # Sudan World Food Prices Dashboard
#
# The aim of this project is to build an interactive dashboard that displays the prices of staple foods in Sudan from  January 15 2001 to November 15, 2023 using data from the world food database.

# %%
import pandas as pd
import numpy as np
import panel as pn
pn.extension('tabulator')
import hvplot.pandas
import holoviews as hv
hv.extension('bokeh')
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
df = pd.read_csv('wfp_food_prices_sdn.csv')
df.head()
# Out:
#          date      admin1            admin2            market  latitude  \
# 0       #date  #adm1+name        #adm2+name  #loc+market+name  #geo+lat
# 1  2001-01-15   Blue Nile           Damazin           Damazin   11.7891
# 2  2001-01-15     Gedaref  Al Gedaref Rural        El Gedarif     14.04
# 3  2001-01-15    Khartoum       Jebal Aulya          Khartoum   15.5126
# 4  2001-01-15    Khartoum       Jebal Aulya          Khartoum   15.5126
#
#   longitude            category        commodity        unit  \
# 0  #geo+lon          #item+type       #item+name  #item+unit
# 1   34.3592  cereals and tubers  Sorghum (white)       90 KG
# 2     35.38  cereals and tubers  Sorghum (white)       90 KG
# 3   32.5436  cereals and tubers           Millet       90 KG
# 4   32.5436  cereals and tubers  Sorghum (white)       90 KG
#
#           priceflag         pricetype   currency   price    usdprice
# 0  #item+price+flag  #item+price+type  #currency  #value  #value+usd
# 1            actual         Wholesale        SDG    46.0     17.8728
# 2            actual         Wholesale        SDG   51.67     20.0758
# 3            actual         Wholesale        SDG   77.29     30.0302
# 4            actual         Wholesale        SDG    63.9     24.8277

# %% [markdown]
# # Data Preprocessing

# %%
df.columns
# Out:
# Index(['date', 'admin1', 'admin2', 'market', 'latitude', 'longitude',
#        'category', 'commodity', 'unit', 'priceflag', 'pricetype', 'currency',
#        'price', 'usdprice'],
#       dtype='object')

# %%
# Rename columns and remove non-food data 

new_column_names = {
    'admin1': 'state',
    'admin2': 'settlement',
}
df.rename(columns=new_column_names, inplace=True)
df = df.drop(0)
df = df[df['category'] != 'non-food']
df['unit'] = df['unit'].str.replace(' KG', '').astype(float)
df.rename(columns={'unit': 'unit(KG)'}, inplace=True)
df.head()
# Out:
#          date      state        settlement      market latitude longitude  \
# 1  2001-01-15  Blue Nile           Damazin     Damazin  11.7891   34.3592
# 2  2001-01-15    Gedaref  Al Gedaref Rural  El Gedarif    14.04     35.38
# 3  2001-01-15   Khartoum       Jebal Aulya    Khartoum  15.5126   32.5436
# 4  2001-01-15   Khartoum       Jebal Aulya    Khartoum  15.5126   32.5436
# 5  2001-01-15   Khartoum       Jebal Aulya    Khartoum  15.5126   32.5436
#
#              category        commodity  unit(KG) priceflag  pricetype  \
# 1  cereals and tubers  Sorghum (white)      90.0    actual  Wholesale
# 2  cereals and tubers  Sorghum (white)      90.0    actual  Wholesale
# 3  cereals and tubers           Millet      90.0    actual  Wholesale
# 4  cereals and tubers  Sorghum (white)      90.0    actual  Wholesale
# 5  cereals and tubers            Wheat      90.0    actual  Wholesale
#
#   currency  price usdprice
# 1      SDG   46.0  17.8728
# 2      SDG  51.67  20.0758
# 3      SDG  77.29  30.0302
# 4      SDG   63.9  24.8277
# 5      SDG   81.5   31.666

# %%
#Convert object types
df['date'] = pd.to_datetime(df['date'])
df['price'] = df['price'].astype(float)
df['usdprice'] = df['usdprice'].astype(float)

# Create new price per KG column 
df['price per KG(SDG)'] = df['price']/ df['unit(KG)']
df['price per KG(USD)'] = df['usdprice']/ df['unit(KG)']

# Create new year column 
df['year'] = df['date'].dt.year

df['year'] = df['year'].astype(int)
df.head()
# Create new region column 
region_mapping = {
    'Khartoum': 'Central', 'North Kordofan': 'Central', 'Al Gezira': 'Central',
    'Northern': 'North', 'Nile': 'North',
    'South Kordofan': 'South', 'Blue Nile': 'South', 'White Nile': 'South',
    'Eastern Darfur': 'South', 'West Kordofan': 'South',
    'Kassala': 'East', 'Red Sea': 'East', 'Gedaref': 'East', 'Sennar': 'East',
    'North Darfur': 'West', 'South Darfur': 'West',
    'West Darfur': 'West', 'Central Darfur': 'West'
}


df['region'] = df['state'].map(region_mapping)
df.head()
# Out:
#         date      state        settlement      market latitude longitude  \
# 1 2001-01-15  Blue Nile           Damazin     Damazin  11.7891   34.3592
# 2 2001-01-15    Gedaref  Al Gedaref Rural  El Gedarif    14.04     35.38
# 3 2001-01-15   Khartoum       Jebal Aulya    Khartoum  15.5126   32.5436
# 4 2001-01-15   Khartoum       Jebal Aulya    Khartoum  15.5126   32.5436
# 5 2001-01-15   Khartoum       Jebal Aulya    Khartoum  15.5126   32.5436
#
#              category        commodity  unit(KG) priceflag  pricetype  \
# 1  cereals and tubers  Sorghum (white)      90.0    actual  Wholesale
# 2  cereals and tubers  Sorghum (white)      90.0    actual  Wholesale
# 3  cereals and tubers           Millet      90.0    actual  Wholesale
# 4  cereals and tubers  Sorghum (white)      90.0    actual  Wholesale
# 5  cereals and tubers            Wheat      90.0    actual  Wholesale
#
#   currency  price  usdprice  price per KG(SDG)  price per KG(USD)  year  \
# 1      SDG  46.00   17.8728           0.511111           0.198587  2001
# 2      SDG  51.67   20.0758           0.574111           0.223064  2001
# 3      SDG  77.29   30.0302           0.858778           0.333669  2001
# 4      SDG  63.90   24.8277           0.710000           0.275863  2001
# 5      SDG  81.50   31.6660           0.905556           0.351844  2001
#
#     region
# 1    South
# 2     East
# 3  Central
# 4  Central
# 5  Central

# %%
# Make FataFrame Pipeline Interactive 
idf = df.interactive()

# %% [markdown]
# # (1) Food prices over time by region

# %%
# Define Panel widgets 

import panel as pn

# Extract years from the 'Date' column
years = sorted(df['date'].dt.year.unique())
year_slider = pn.widgets.IntSlider(name='Year slider', start=2001, end=2023, value=2005)
year_slider.servable()
# # Display the slider
year_slider
# Out:
# IntSlider(end=2023, name='Year slider', start=2001, value=2005)

# %%
# Radio Buttons for Currency 
yaxis_price = pn.widgets.RadioButtonGroup(
    name='Y axis',
    options=['price per KG(SDG)','price per KG(USD)',],
    button_type='success'
)

# %%
regions = ['South', 'East', 'Central', 'West', 'North']

price_pipeline = (
    idf[
        (idf.year <= year_slider) &
        (idf.region.isin(regions))
    ]
    .groupby(['region', 'year'])[yaxis_price].mean()
    .to_frame()
    .reset_index()
    .sort_values(by='year')
    .reset_index(drop=True)
)

# %%
price_plot = price_pipeline.hvplot(x='year', by='region', y=yaxis_price, line_width=2, title='Price of food by region')

# Display the plot
price_plot
# Out:
# <div id='cdb27c4e-4da3-4cc1-a090-95c2c509338e'>
#   <div id="a487ad9a-aa91-4609-b20a-efc6f31a7160" data-root-id="cdb27c4e-4da3-4cc1-a090-95c2c509338e" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"b05c661e-fd85-4ccb-9681-dbe58d60d7c4":{"version":"3.2.1","title":"Bokeh Application","roots":[{"type":"object","name":"Row","id":"cdb27c4e-4da3-4cc1-a090-95c2c509338e","attributes":{"name":"Row20813","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"type":"object","name":"ImportedStyleSheet","id":"9f7b434d-ad4b-4710-b95c-c1862dae48c1","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.3/dist/css/loading.css"}},{"type":"object","name":"ImportedStyleSheet","id":"5885f68d-33a1-4739-ab24-03e51ac4cda6","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.3/dist/css/listpanel.css"}},{"type":"object","name":"ImportedStyleSheet","id":"4e567816-ec49-41bf-800d-d63332f2281a","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.3/dist/bundled/theme/default.css"}},{"type":"object","name":"ImportedStyleSheet","id":"e8f0c296-21aa-4edb-8d4e-71bfa6f81084","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.3/dist/bundled/theme/native.css"}}],"margin":0,"align":"start","children":[{"type":"object","name":"panel.models.layout.Column","id":"d9ac9542-7290-4f24-bc42-4f2bf6f432eb","attributes":{"name":"Column20810","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"9f7b434d-ad4b-4710-b95c-c1862dae48c1"},{"id":"5885f68d-33a1-4739-ab24-03e51ac4cda6"},{"id":"4e567816-ec49-41bf-800d-d63332f2281a"},{"id":"e8f0c296-21aa-4edb-8d4e-71bfa6f81084"}],"margin":0,"align":"start","children":[{"type":"object","name":"panel.models.layout.Column","id":"467b4a4e-2219-40cc-914b-1a61ed758ee8","attributes":{"name":"Column20793","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"9f7b434d-ad4b-4710-b95c-c1862dae48c1"},{"id":"5885f68d-33a1-4739-ab24-03e51ac4cda6"},{"id":"4e567816-ec49-41bf-800d-d63332f2281a"},{"id":"e8f0c296-21aa-4edb-8d4e-71bfa6f81084"}],"margin":0,"align":"start","children":[{"type":"object","name":"Slider","id":"6523dd26-1fdf-43a7-a3f5-c09235772abc","attributes":{"stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"9f7b434d-ad4b-4710-b95c-c1862dae48c1"},{"id":"4e567816-ec49-41bf-800d-d63332f2281a"},{"id":"e8f0c296-21aa-4edb-8d4e-71bfa6f81084"}],"margin":[5,10],"align":"start","title":"Year slider","start":2001,"end":2023,"value":2005}},{"type":"object","name":"RadioButtonGroup","id":"5d75750e-b58d-49a0-8efc-39068db3dc85","attributes":{"button_type":"success","css_classes":["solid"],"stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"9f7b434d-ad4b-4710-b95c-c1862dae48c1"},{"type":"object","name":"ImportedStyleSheet","id":"c8741e57-37fb-4845-9fdb-9ce48a51f380","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.3/dist/css/button.css"}},{"id":"4e567816-ec49-41bf-800d-d63332f2281a"},{"id":"e8f0c296-21aa-4edb-8d4e-71bfa6f81084"}],"margin":[5,10],"align":"start","labels":["price per KG(SDG)","price per KG(USD)"],"active":0}}]}},{"type":"object","name":"Figure","id":"29293a10-13ad-4bc2-9827-dd4df5889918","attributes":{"width":700,"height":300,"margin":[5,10],"sizing_mode":"fixed","align":"start","x_range":{"type":"object","name":"Range1d","id":"e7d45f4e-b989-4b99-9e1f-cd89a45b19c5","attributes":{"tags":[[["year","year",null]],[]],"start":2001.0,"end":2005.0,"reset_start":2001.0,"reset_end":2005.0}},"y_range":{"type":"object","name":"Range1d","id":"0abb2f22-5ede-4fd3-affd-e80ee9477715","attributes":{"tag ...

# %% [markdown]
# # (2) Table - Food prices over time by region

# %%
price_table = price_pipeline.pipe(pn.widgets.Tabulator, pagination='remote', page_size = 10, sizing_mode='stretch_width')
price_table
# Out:
# <div id='dd1eec8f-44e6-4f7b-9b5c-7a6d005717a7'>
#   <div id="b13e2e09-fa93-45f2-8c06-85f4a246de88" data-root-id="dd1eec8f-44e6-4f7b-9b5c-7a6d005717a7" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"b721318a-4476-4b24-b629-36f11538335f":{"version":"3.2.1","title":"Bokeh Application","roots":[{"type":"object","name":"Row","id":"dd1eec8f-44e6-4f7b-9b5c-7a6d005717a7","attributes":{"name":"Row21017","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"type":"object","name":"ImportedStyleSheet","id":"88441fe8-c73d-48f2-88ac-78b95b52c634","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.3/dist/css/loading.css"}},{"type":"object","name":"ImportedStyleSheet","id":"962ef344-7d31-4fd2-b8e2-17c8c61d600a","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.3/dist/css/listpanel.css"}},{"type":"object","name":"ImportedStyleSheet","id":"d7104909-ab13-4d24-8131-fa6f775d0313","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.3/dist/bundled/theme/default.css"}},{"type":"object","name":"ImportedStyleSheet","id":"fd8760b8-7a07-4ff6-96bc-62db629ded5c","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.3/dist/bundled/theme/native.css"}}],"margin":0,"sizing_mode":"stretch_width","align":"start","children":[{"type":"object","name":"panel.models.layout.Column","id":"4bdb00ac-392b-4ec2-bbb3-80f9aa691efa","attributes":{"name":"Column21014","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"88441fe8-c73d-48f2-88ac-78b95b52c634"},{"id":"962ef344-7d31-4fd2-b8e2-17c8c61d600a"},{"id":"d7104909-ab13-4d24-8131-fa6f775d0313"},{"id":"fd8760b8-7a07-4ff6-96bc-62db629ded5c"}],"margin":0,"sizing_mode":"stretch_width","align":"start","children":[{"type":"object","name":"panel.models.layout.Column","id":"89e89ca9-4f3a-4a48-98bd-7436b99eaa95","attributes":{"name":"Column20996","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"88441fe8-c73d-48f2-88ac-78b95b52c634"},{"id":"962ef344-7d31-4fd2-b8e2-17c8c61d600a"},{"id":"d7104909-ab13-4d24-8131-fa6f775d0313"},{"id":"fd8760b8-7a07-4ff6-96bc-62db629ded5c"}],"margin":0,"align":"start","children":[{"type":"object","name":"Slider","id":"b6a6a402-297d-497f-bcd4-e86e9313d8fb","attributes":{"stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"88441fe8-c73d-48f2-88ac-78b95b52c634"},{"id":"d7104909-ab13-4d24-8131-fa6f775d0313"},{"id":"fd8760b8-7a07-4ff6-96bc-62db629ded5c"}],"margin":[5,10],"align":"start","title":"Year slider","start":2001,"end":2023,"value":2005}},{"type":"object","name":"RadioButtonGroup","id":"9acdf45f-7185-4432-82e2-fabd6522b6cb","attributes":{"button_type":"success","css_classes":["solid"],"stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"88441fe8-c73d-48f2-88ac-78b95b52c634"},{"type":"object","name":"ImportedStyleSheet","id":"f1f473f4-c958-433a-8073-1d8cb70c63c6","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.3/dist/css/button.css"}},{"id":"d7104909-ab13-4d24-8131-fa6f775d0313"},{"id":"fd8760b8-7a07-4ff6-96bc-62db629ded5c"}],"margin":[5,10],"align":"start","labels":["price per KG(SDG)","price per KG(USD)"],"active":0}}]}},{"type":"object","name":"panel.models.layout.Column","id":"f6747326-e304-4f35-882e-33c825712da2","attributes":{"name":"Column21011","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"88441fe8-c73d-48f2-88ac-78b95b52c634"},{"id":"962ef344-7d31-4fd2-b8e2-17c8c61d600a"},{"id": ...

# %%
df['commodity'].unique()
# Out:
# array(['Sorghum (white)', 'Millet', 'Wheat', 'Sorghum',
#        'Sorghum (food aid)'], dtype=object)

# %% [markdown]
# # (3) Bar chart with food prices by State

# %%
df['state'].unique()
# Out:
# array(['Blue Nile', 'Gedaref', 'Khartoum', 'North Kordofan',
#        'North Darfur', 'Northern', 'Eastern Darfur', 'Kassala', 'Red Sea',
#        'South Darfur', 'West Darfur', 'White Nile', 'South Kordofan',
#        'Central Darfur', 'West Kordofan', 'Al Gezira', 'Nile', 'Sennar'],
#       dtype=object)

# %%
states= ['Blue Nile', 'Gedaref', 'Khartoum', 'North Kordofan','North Darfur', 'Northern', 'Eastern Darfur', 'Kassala', 'Red Sea','South Darfur', 'West Darfur', 'White Nile', 'South Kordofan','Central Darfur', 'West Kordofan', 'Al Gezira', 'Nile', 'Sennar']

state_bar_pipeline = (
    idf[
        (idf.year == year_slider) &
        (idf.state.isin(states))
    ]
    .groupby(['year', 'state'])[yaxis_price].mean()
    .to_frame()
    .reset_index()
    .sort_values(by='year')  
    .reset_index(drop=True)
)

# %%
state_bar_plot = state_bar_pipeline.hvplot(kind='bar', 
                                                     x='state', 
                                                     y=yaxis_price, 
                                                     title='Food prices by state',
                                          rot=45)

state_bar_plot
# Out:
# <div id='99ca5bbb-d3f9-47bb-b488-1bbbd477d3ba'>
#   <div id="f8af893a-5411-4724-a181-f4c87e09a46e" data-root-id="99ca5bbb-d3f9-47bb-b488-1bbbd477d3ba" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"f7238d6a-b48b-48fd-aa69-8b3e6fe128a5":{"version":"3.2.1","title":"Bokeh Application","roots":[{"type":"object","name":"Row","id":"99ca5bbb-d3f9-47bb-b488-1bbbd477d3ba","attributes":{"name":"Row21955","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"type":"object","name":"ImportedStyleSheet","id":"73b92d2a-53c3-4f39-83f6-b992efdaee30","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.3/dist/css/loading.css"}},{"type":"object","name":"ImportedStyleSheet","id":"79381f96-bc08-4194-b8bf-a2aa0aad4aa9","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.3/dist/css/listpanel.css"}},{"type":"object","name":"ImportedStyleSheet","id":"692eb889-ef53-4e28-8ee7-0fa8f5c8763c","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.3/dist/bundled/theme/default.css"}},{"type":"object","name":"ImportedStyleSheet","id":"14991b64-a730-4ea7-95ec-d69b6a84f823","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.3/dist/bundled/theme/native.css"}}],"margin":0,"align":"start","children":[{"type":"object","name":"panel.models.layout.Column","id":"b416c049-b806-4791-977e-f1e3876a94c4","attributes":{"name":"Column21952","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"73b92d2a-53c3-4f39-83f6-b992efdaee30"},{"id":"79381f96-bc08-4194-b8bf-a2aa0aad4aa9"},{"id":"692eb889-ef53-4e28-8ee7-0fa8f5c8763c"},{"id":"14991b64-a730-4ea7-95ec-d69b6a84f823"}],"margin":0,"align":"start","children":[{"type":"object","name":"panel.models.layout.Column","id":"2501f0a9-2046-4a8f-b3f2-496d7a3ff2b8","attributes":{"name":"Column21935","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"73b92d2a-53c3-4f39-83f6-b992efdaee30"},{"id":"79381f96-bc08-4194-b8bf-a2aa0aad4aa9"},{"id":"692eb889-ef53-4e28-8ee7-0fa8f5c8763c"},{"id":"14991b64-a730-4ea7-95ec-d69b6a84f823"}],"margin":0,"align":"start","children":[{"type":"object","name":"Slider","id":"a215bb7a-d4b8-4bb8-a267-a3c596c5da10","attributes":{"stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"73b92d2a-53c3-4f39-83f6-b992efdaee30"},{"id":"692eb889-ef53-4e28-8ee7-0fa8f5c8763c"},{"id":"14991b64-a730-4ea7-95ec-d69b6a84f823"}],"margin":[5,10],"align":"start","title":"Year slider","start":2001,"end":2023,"value":2005}},{"type":"object","name":"RadioButtonGroup","id":"10cd87dc-6854-4b4e-bb71-2fa9528459da","attributes":{"button_type":"success","css_classes":["solid"],"stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"73b92d2a-53c3-4f39-83f6-b992efdaee30"},{"type":"object","name":"ImportedStyleSheet","id":"574874b7-7b8f-4e6b-83f3-1e3f50929852","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.3/dist/css/button.css"}},{"id":"692eb889-ef53-4e28-8ee7-0fa8f5c8763c"},{"id":"14991b64-a730-4ea7-95ec-d69b6a84f823"}],"margin":[5,10],"align":"start","labels":["price per KG(SDG)","price per KG(USD)"],"active":0}}]}},{"type":"object","name":"Figure","id":"5bd4c19b-2d2e-46d8-95f7-d0c6410d20ce","attributes":{"width":700,"height":300,"margin":[5,10],"sizing_mode":"fixed","align":"start","x_range":{"type":"object","name":"FactorRange","id":"29d7ca18-b0dd-4484-a93d-25bc22345fc0","attributes":{"tags":[[["state","state",null]],[]],"factors":["Blue Nile","Eastern Darfur","Gedaref","Kassala","Khartoum","North Darfur","North Kordofan","Northern","Red Sea","South Darfur","South Kordofan","West Darfur", ...

# %% [markdown]
# # (4) Bar Chart with Food prices by commodity

# %%
commodities =['Sorghum (white)', 'Millet', 'Wheat', 'Sorghum','Sorghum (food aid)']

commodity_bar_pipeline = (
    idf[
        (idf.year == year_slider) &
        (idf.commodity.isin(commodities))
    ]
    .groupby(['year','commodity'])[yaxis_price].sum()
    .to_frame()
    .reset_index()
    .sort_values(by='year')  
    .reset_index(drop=True)
)

# %%
commodity_bar_plot = commodity_bar_pipeline.hvplot(kind='bar', 
                                                     x='commodity', 
                                                     y=yaxis_price, 
                                                     title='Food prices by commodity',
                                          rot=45)
commodity_bar_plot
# Out:
# <div id='85d0d84e-71f3-453c-bc97-2aabec639b32'>
#   <div id="c3ecff08-7a7b-4ac2-b78d-5c281d6ff257" data-root-id="85d0d84e-71f3-453c-bc97-2aabec639b32" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"c34ba48d-9117-4e1b-86fc-860788e59b41":{"version":"3.2.1","title":"Bokeh Application","roots":[{"type":"object","name":"Row","id":"85d0d84e-71f3-453c-bc97-2aabec639b32","attributes":{"name":"Row22911","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"type":"object","name":"ImportedStyleSheet","id":"16cb8fa6-be3d-42fc-82b9-c144721fc823","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.3/dist/css/loading.css"}},{"type":"object","name":"ImportedStyleSheet","id":"5c149dd4-3ce5-432c-afbd-6b617a5570b6","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.3/dist/css/listpanel.css"}},{"type":"object","name":"ImportedStyleSheet","id":"8d1fdc73-8c65-411e-80e4-d0f5d4ce0812","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.3/dist/bundled/theme/default.css"}},{"type":"object","name":"ImportedStyleSheet","id":"c40205b9-7d67-4816-bc15-2f40aa13b64c","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.3/dist/bundled/theme/native.css"}}],"margin":0,"align":"start","children":[{"type":"object","name":"panel.models.layout.Column","id":"3276b45a-5e1c-4ab3-8174-010a0f08fed7","attributes":{"name":"Column22908","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"16cb8fa6-be3d-42fc-82b9-c144721fc823"},{"id":"5c149dd4-3ce5-432c-afbd-6b617a5570b6"},{"id":"8d1fdc73-8c65-411e-80e4-d0f5d4ce0812"},{"id":"c40205b9-7d67-4816-bc15-2f40aa13b64c"}],"margin":0,"align":"start","children":[{"type":"object","name":"panel.models.layout.Column","id":"367106d5-ac60-4650-af62-d9c80d57642f","attributes":{"name":"Column22891","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"16cb8fa6-be3d-42fc-82b9-c144721fc823"},{"id":"5c149dd4-3ce5-432c-afbd-6b617a5570b6"},{"id":"8d1fdc73-8c65-411e-80e4-d0f5d4ce0812"},{"id":"c40205b9-7d67-4816-bc15-2f40aa13b64c"}],"margin":0,"align":"start","children":[{"type":"object","name":"Slider","id":"b456325e-0998-4d0a-90fb-ea731d6a8e90","attributes":{"stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"16cb8fa6-be3d-42fc-82b9-c144721fc823"},{"id":"8d1fdc73-8c65-411e-80e4-d0f5d4ce0812"},{"id":"c40205b9-7d67-4816-bc15-2f40aa13b64c"}],"margin":[5,10],"align":"start","title":"Year slider","start":2001,"end":2023,"value":2005}},{"type":"object","name":"RadioButtonGroup","id":"a22ad8a3-fd0b-49c0-ad65-6aaab89523db","attributes":{"button_type":"success","css_classes":["solid"],"stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"16cb8fa6-be3d-42fc-82b9-c144721fc823"},{"type":"object","name":"ImportedStyleSheet","id":"a196aae3-d627-46f0-8015-fa20828c3f35","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.3/dist/css/button.css"}},{"id":"8d1fdc73-8c65-411e-80e4-d0f5d4ce0812"},{"id":"c40205b9-7d67-4816-bc15-2f40aa13b64c"}],"margin":[5,10],"align":"start","labels":["price per KG(SDG)","price per KG(USD)"],"active":0}}]}},{"type":"object","name":"Figure","id":"80c185b6-5279-4829-bf99-a426f1eb1291","attributes":{"width":700,"height":300,"margin":[5,10],"sizing_mode":"fixed","align":"start","x_range":{"type":"object","name":"FactorRange","id":"b0ebf1d9-53af-4865-ae49-94ccdee57b43","attributes":{"tags":[[["commodity","commodity",null]],[]],"factors":["Millet","Sorghum","Sorghum (white)","Wheat"]}},"y_range":{"type":"object","name":"Range1d","id":"fd45a194-628a-44d2-9f30-fa70830f5e89","attributes":{" ...

# %%
# Final Dashboard 

# Create Markdown pane for data source information
data_source_info = pn.pane.Markdown("Data source: Food Prices 2024 © World Food Programme")

# Update your existing layout to include the data source information
template = pn.template.FastListTemplate(
    title='Sudan Food Prices', 
    sidebar=[pn.pane.Markdown("# Food Inflation Over time"), 
             pn.pane.Markdown("#### Between 2001 and 2023, Sudan experienced significant fluctuations in food inflation, driven by a combination of internal and external factors. The country's economy faced challenges such as political instability, conflicts, economic sanctions, and natural disasters, all of which impacted food production, distribution, and pricing. During this period, Sudan witnessed periods of high food inflation, particularly in the early 2000s and again in the 2010s. The secession of South Sudan in 2011 further strained the economy, as Sudan lost a significant portion of its oil revenues, exacerbating inflationary pressures."), 
             pn.pane.PNG('sudan-map.png', sizing_mode='scale_both')],
    main=[
        pn.Row(price_plot, state_bar_plot, height=400),
        pn.GridBox(
            price_table,
            commodity_bar_plot,
            ncols=2,
            align='start',
            sizing_mode='scale_width'
        ),
        data_source_info  # Add the data source information to the layout
    ]
)

template.show()
# Out:
# Launching server at http://localhost:63944
