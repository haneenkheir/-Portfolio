# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn.linear_model import LinearRegression
# %matplotlib inline

# %% [markdown]
# Task: Use the data in the relevant columns to determine how age affects insurance costs
# plot scatterplot
# fit linear regression model and make predictions
# plot scatter plot with best fit line

# %%
# Load data 
df=pd.read_csv('insurance.csv')

# %%
# Exploratory analysis
df.head()
# data.info()
# data.isnull().sum()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
# Select data rows/columns  
 
x = df['age'].values
y = df['charges'].values

plt.scatter(X,y,color = 'b')
plt.xlabel('Age')
plt.ylabel('Charges')
plt.show()

# %%
print(x.shape)
# Out:
# (1338,)

# %%
# Reshape data 
y=y.reshape(-1,1)
x=x.reshape(-1,1)
# Fit linear regression model 

insurance_cost_model = LinearRegression()
insurance_cost_model.fit(X,y)
# Out:
# LinearRegression()

# %%
# Make predictions with linear regression model 
unk_x = [[65]]

x_pred = np.append(X, unk_x).reshape(-1,1)
y_pred = insurance_cost_model.predict(x_pred)
print("A 65 year old's insurance will cost:", insurance_cost_model.predict(unk_x))
# Out:
# A 65 year old's insurance will cost: [19917.85521941]

# %%
# Plot scatterplot with line of best fit 
y_pred = insurance_cost_model.predict(x)
plt.scatter(x,y, color = 'b')
plt.plot(x,insurance_cost_model.predict(x),color = 'r')
plt.title('Age vs Insurance Cost')
plt.xlabel('Age')
plt.ylabel('Insurance cost')
plt.show()
